# %% [markdown]
# # 1-1 データのダウンロード
# ---
# [書式] GETリクエストでパラメータを送信する
# http://example.com?key1=v1&key2=v2&...
#
# ---
# 任意のパラメータをつけてリクエスト送信
# znに郵便番号

# %%
import urllib.request
import urllib.parse

API = "http://api.aoikujira.com/zip/xml/get.php"

values = {'fmt':'xml', 'zn':'2460038'}

params = urllib.parse.urlencode(values)

# リクエスト用のURL作成
url = API+"?"+params
print("url=", url)

# download
data = urllib.request.urlopen(url).read()
text = data.decode("utf-8")
print(text)
# Out:
# url= http://api.aoikujira.com/zip/xml/get.php?fmt=xml&zn=2460038
# <?xml version="1.0" encoding="utf-8" ?>
# <address result="1">
# <header>
#   <result>1</result>
#   <api>api.aoikujira.com/zip</api>
#   <version>1.1</version>
# </header>
# <value>
#   <zip>2460038</zip>
#   <ken>神奈川県</ken>
#   <shi>横浜市瀬谷区</shi>
#   <cho>宮沢</cho>
#   <disp>神奈川県横浜市瀬谷区宮沢</disp>
#   <kenkana>カナガワケン</kenkana>
#   <shikana>ヨコハマシセヤク</shikana>
#   <chokana>ミヤザワ</chokana>
# </value>
# </address>

# %% [markdown]
# # 1-2 BeautifulSoupでスクレイピング

# %%
from bs4 import BeautifulSoup

html = """
<html><body>
    <ul>
      <li><a href="http://uta.pw">uta</a></li>
      <li><a href="http://oto.chu.jp">oto</a></li>
    </ul>
</body></html>
"""

# htmlを解析
soup = BeautifulSoup(html, 'html.parser')

# find_all()メソッドで取り出す
links = soup.find_all("a")

#リンク一覧表示
for a in links:
    href = a.attrs['href']
    text = a.string
    print(text, ">", href)
# Out:
# uta > http://uta.pw
# oto > http://oto.chu.jp

# %%
from bs4 import BeautifulSoup
import urllib.request as req

url = "http://api.aoikujira.com/zip/xml/1500042"
print(url)
# urlopenでデータを取得
res = req.urlopen(url)

# BeautifulSoupで解析
soup = BeautifulSoup(res, "html.parser")
print(soup)
print("--------------------------------")
# 任意のデータ取得
ken = soup.find("ken").string
shi = soup.find("shi").string
cho = soup.find("cho").string
print(ken, shi, cho)
# Out:
# http://api.aoikujira.com/zip/xml/1500042
# <?xml version="1.0" encoding="utf-8" ?>
# <address result="1">
# <header>
# <result>1</result>
# <api>api.aoikujira.com/zip</api>
# <version>1.1</version>
# </header>
# <value>
# <zip>1500042</zip>
# <ken>東京都</ken>
# <shi>渋谷区</shi>
# <cho>宇田川町</cho>
# <disp>東京都渋谷区宇田川町</disp>
# <kenkana>トウキョウト</kenkana>
# <shikana>シブヤク</shikana>
# <chokana>ウダガワチョウ</chokana>
# </value>
# </address>
# --------------------------------
# 東京都 渋谷区 宇田川町

# %% [markdown]
# ### CSSセレクタを使う
# |メソッド|解説|
# |:--|--|
# |soup.select_one(セレクタ)|CSSセレクタで要素を一つ取り出す|
# |soup.select(セレクタ)|CSSセレクタで複数要素を取り出しリスト型で返す|

# %%
from bs4 import BeautifulSoup
# 解析対象となるHTML
html = """
<html><body>
<div id="meigen">
    <h1>トルストイの名言</h1>
    <ul class="items">
      <li>汝の心に教えよ、心に学ぶな</li>
      <li>謙虚な人は誰からも好かれる。</li>
      <li>強い人々は、いつも気取らない。</li>
    </ul>
</div>
</body></html>
"""

# HTMLを解析
soup = BeautifulSoup(html, 'html.parser')

# 必要な部分をCSSクエリで取り出す
# タイトル部分を取得
h1 = soup.select_one("div#meigen > h1").string
print("h1 =", h1)

# リスト部分を取得
li_list = soup.select("div#meigen > ul.items > li")
for li in li_list:
    print("li =", li.string)
# Out:
# h1 = トルストイの名言
# li = 汝の心に教えよ、心に学ぶな
# li = 謙虚な人は誰からも好かれる。
# li = 強い人々は、いつも気取らない。

# %% [markdown]
# ### Yahoo!ファイナンスの為替情報取得

# %%
from bs4 import BeautifulSoup
import urllib.request as req

# 為替情報XML取得
url = "http://stocks.finance.yahoo.co.jp/stocks/detail/?code=usdjpy"
res = req.urlopen(url)
print(url)
print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")

# HTML解析
soup = BeautifulSoup(res, "html.parser")
print(soup)
print("----------------------------------")

# 任意のデータ抽出
price = soup.select_one(".stoksPrice").string
print("usd/jpy=", price)
# Out:
# http://stocks.finance.yahoo.co.jp/stocks/detail/?code=usdjpy
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ja">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="text/css" http-equiv="Content-Style-Type">
# <meta content="text/javascript" http-equiv="Content-Script-Type">
# <meta content="464062600275671" property="fb:app_id">
# <meta content="Yahoo!ファイナンス" property="og:site_name">
# <meta content="article" property="og:type">
# <meta content="https://stocks.finance.yahoo.co.jp:443/stocks/detail/?code=usdjpy" property="og:url">
# <meta content="https://s.yimg.jp/images/finance/common/image/ogp.png" property="og:image">
# <meta content="アメリカ　ドル / 日本　円の取引値、チャートをご覧いただけます。株価、株式など投資やマネーの総合情報サイト-Yahoo!ファイナンス" name="description">
# <meta content="アメリカ　ドル / 日本　円の取引値、チャートをご覧いただけます。株価、株式など投資やマネーの総合情報サイト-Yahoo!ファイナンス" property="og:description">
# <meta content="株価,チャート,日経平均,銘柄,投資信託,外国為替,ドル,ユーロ,ダウ,ナスダック,Dow,NASDAQ" name="keywords">
# <meta content="60" http-equiv="Refresh">
# <title>アメリカ　ドル / 日本　円【USDJPY】：外国為替 - Yahoo!ファイナンス</title>
# <meta content="アメリカ　ドル / 日本　円【USDJPY】：外国為替 - Yahoo!ファイナンス" property="og:title">
# <link href="https://s.yimg.jp/images/finance/common/css/master-finance3.css?date=20170515_2" media="all" rel="stylesheet" type="text/css">
# <link href="https://s.yimg.jp/images/finance/stock/css/stockDetail-min.css?date=20170515_2" media="all" rel="stylesheet" type="text/css">
# <link href="http://finance.mobile.yahoo.co.jp/p/finance/details/top?code=USDJPY=X" media="handheld" rel="alternate" type="text/html"/>
# <link href="android-app://jp.co.yahoo.android.finance/yjfinance-appindexing/m.finance.yahoo.co.jp/stock?code=USDJPY=X" rel="alternate"/></link></link></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></head>
# <body class="yj950-2">
# <!--wrapper start-->
# <div id="wrapper">
# <!--header start-->
# <div id="header">
# <span class="yj-guid"><a id="pagetop" name="pagetop"></a><img alt="このページの先頭です" height="1" src="https://s.yimg.jp/images/clear.gif" width="1"/></span>
# <span class="yj-skip"><a href="#contents-start"><img alt="このページの本文へ" height="1" src="https://s.yimg.jp/images/clear.gif" width="1"/></a></span>
# <!--MHCSS -->
# <!-- SpaceID=0 robot -->
# <!--/MHCSS -->
# <!--MH -->
# <!-- SpaceID=0 robot -->
# <!--/MH -->
# <div id="heademg">
# <div id="emg3">
# <!-- SpaceID=0 robot -->
# </div>
# <div id="emg2">
# <!-- SpaceID=0 robot -->
# </div>
# <div id="emg">
# <!-- SpaceID=0 robot -->
# </div>
# </div>
# </div><!--/#header end-->
# <!--/header end-->
# <hr class="separation">
# <!--contents start-->
# <div id="contents">
# <!--empty-->
# <!--/empty-->
# <div id="contents-header">
# <!--================================ GLOBAL NAVIGATION ====================================-->
# <!--グローバルナビ-->
# <div id="globalNavWrapper">
# <div id="navi">
# <div class="clearFix" id="globalDate">
# <em>
# <a href="http://rdsig.yahoo.co.jp/finance/stocks/g_navi/purchase_history/RV=1/RU=aHR0cHM6Ly9kZXRhaWwud2FsbGV0LnlhaG9vLmNvLmpwL2hpc3Rvcnk-">利用明細</a> - <a href="http://rdsig.yahoo.co.jp/finance/stocks/g_navi/alert/RV=1/RU=aHR0cHM6Ly9zdG9ja3MuZmluYW5jZS55YWhvby5jby5qcC9zdG9ja3MvYWxlcnQv">アラート</a> - <a href="http://rdsig.yahoo.co.jp/finance/stocks/g_navi/customize/RV=1/RU=aHR0cHM6Ly9pbmZvLmZpbmFuY2UueWFob28uY28uanAvcG9ydGZvbGlvL2NvbG9yLz8uZG9uZT1odHRwcyUzQSUyRiUyRnN0b2Nrcy5maW5hbmNlLnlhaG9vLmNvLmpwJTNBNDQzJTJGc3RvY2tzJTJGZGV0YWlsJTJGJTNGY29kZSUzRHVzZGpweSYuaW50bD1qcA--">表示設定</a>  <span class="ymuiArrow1"><a href="http://rdsig.yahoo.co.jp/finance/stocks/g_navi/sitemap/RV=1/RU=aHR0cHM6Ly9maW5hbmNlLnlhaG9vLmNvLmpwL3NpdGVtYXAv">サイトマップ</a></span></em>
# <p>現在の日時：<strong>5月 15日 23:10</strong> -- 日本の証券市場は終了しました。</p></div>
# </div>
# <div id="globalNav">
# <ul class="selectKabu" id="gnPri">
# <li id="gnPriTop"><a href="https://finance.yahoo.co.jp/" onmousedown="this.href='http://rdsig.yahoo.co.jp/finance/g_navi/1/RV=1/RU=aHR0cHM6Ly9maW5hbmNlLnlhaG9vLmNvLmpwLw--'">トップ</a></li>
# <li id="gnPriKabu"><a href="https://stocks.finance.yahoo.co.jp/" onmousedown="this.href='http://rdsig.yahoo.co.jp/finance/g_navi/2/RV=1/RU=aHR0cHM6Ly9zdG9ja3MuZmluYW5jZS55YWhvby5jby5qcC8-'">株式</a></li>
# <li id="gnPriGrKawase"><a href="https://info.finance.yahoo.co.jp/fx/" onmousedown="this.href='http://rdsig.yahoo.co.jp/finance/g_navi/3/RV=1/RU=aHR0cHM6Ly9pbmZvLmZpbmFuY2UueWFob28uY28uanAvZngv'">FX・為替</a></li>
# <li id="gnPriShintaku"><a href="https://stocks.finance.yahoo.co.jp/funds/" onmousedown="this.href='http://rdsig.yahoo.co.jp/finance/g_navi/4/RV=1/RU=aHR0cHM6Ly9zdG9ja3MuZmluYW5jZS55YWhvby5jby5qcC9mdW5kcy8-'">投資信託</a></li>
# <li id="gnPriKabuyoso"><a href="https://info.finance.yahoo.co.jp/kabuyoso/" onmousedown="this.href='http://rdsig.yahoo.co.jp/finance/g_navi/5/RV=1/RU=aHR0cHM6Ly9pbmZvLmZpbmFuY2UueWFob28uY28uanAva2FidXlvc28v'">株価予想</a></li>
# <li id="gnPriNews"><a href="https://news.finance.yahoo.co.jp/" onmousedown="this.href='http://rdsig.yahoo.co.jp/finance/g_navi/6/RV=1/RU=aHR0cHM6Ly9uZXdzLmZpbmFuY2UueWFob28uY28uanAv'">ニュース</a></li>
# <li id="gnPriKinri"><a href="https://info.finance.yahoo.co.jp/interest/" onmousedown="this.href='http://rdsig.yahoo.co.jp/finance/g_navi/7/RV=1/RU=aHR0cHM6Ly9pbmZvLmZpbmFuY2UueWFob28uY28uanAvaW50ZXJlc3Qv'">金利</a></li>
# <li id="gnPriCompany"><a href="https://profile.yahoo.co.jp/" onmousedown="this.href='http://rdsig.yahoo.co.jp/finance/g_navi
" onmousedown="this.href='http://rdsig.yahoo.co.jp/finance/g_navi/2/10/RV=1/RU=aHR0cHM6Ly9pbmZvLmZpbmFuY2UueWFob28uY28uanAvcHRzLw--'">PTS</a></li>
# <li><a href="https://info.finance.yahoo.co.jp/beginners/stocks/" onmousedown="this.href='http://rdsig.yahoo.co.jp/finance/g_navi/2/11/RV=1/RU=aHR0cHM6Ly9pbmZvLmZpbmFuY2UueWFob28uY28uanAvYmVnaW5uZXJzL3N0b2Nrcy8-'">初心者</a></li>
# <li><a class="blank" href="http://stock.searchina.ne.jp/" onmousedown="this.href='http://rdsig.yahoo.co.jp/finance/g_navi/2/12/RV=1/RE=1495983631/RH=cmRzaWcueWFob28uY28uanA-/RB=/RU=aHR0cDovL3N0b2NrLnNlYXJjaGluYS5uZS5qcC8-/RS=^ADAP5XVVgkebvX6aLAmwW3t8nFfMYY-'">中国株</a></li>
# <li><a href="https://stocks.finance.yahoo.co.jp/us/" onmousedown="this.href='http://rdsig.yahoo.co.jp/finance/g_navi/2/13/RV=1/RU=aHR0cHM6Ly9zdG9ja3MuZmluYW5jZS55YWhvby5jby5qcC91cy8-'">米国株</a></li>
# </ul>
# </div>
# </div>
# <hr id="hrGlobalNavigation">
# <!-- 銘柄検索 -->
# <div id="financeSearch">
# <form action="https://info.finance.yahoo.co.jp/search/" class="floatL" id="search">
# <input id="searchText" name="query" type="text" value=""/>
# <input id="searchButton" type="submit" value=" 株価検索 ">
# </input></form>
# <div class="textLink"><a data-ylk="slk:contents;pos:1" href="https://info.finance.yahoo.co.jp/beginners/">やさしい投資のはじめかた<img alt="" src="https://s.yimg.jp/images/icon/u/bsc/1.0.0/beginner12.png" style="padding-left:3px;margin-bottom: -2px;"/></a></div>
# </div>
# <hr id="hrFinanceSearch">
# <!-- /銘柄検索 -->
# <script language="javascript" type="text/javascript">
# <!--
# (function(){
# /*@cc_on _d=document;eval('var document=_d')@*/
# var defaultTxt = "銘柄名やコード、キーワードを入力";
# var txtObj = document.getElementById("searchText");
# var btnObj = document.getElementById("searchButton");
# if (txtObj.value=="") {txtObj.value=defaultTxt;txtObj.style.color="#999999";}
# txtObj.onfocus = function(){if(this.value==defaultTxt ){this.value="";this.style.color="#333333";}};
# txtObj.onblur  = function(){if(this.value=="" ){this.style.color="#999999"; this.value=defaultTxt;}};
# btnObj.onclick = function(){if(txtObj.value==defaultTxt ){txtObj.value=""}};
# }
# )();
# -->
# </script>
# <!---PORTFOLIO-->
# <div class="portFolioBgMain marB10">
# <div class="portFolioMain clearFix" id="prtfolio">
# <span class="portFolio">
# <ul>
# <li>
# <strong>ポートフォリオ</strong>
#  [ <a data-ylk="slk:pr;pos:0" href="https://info.finance.yahoo.co.jp/pr/portfolio">機能紹介</a><img alt="" src="https://s.yimg.jp/images/icon/u/bsc/1.0.0/beginner12.png" style="vertical-align:bottom;"/> ]</li>
# </ul>
# </span>
# <ul class="portFolioIn">
# <li class="help"><a data-ylk="slk:login;pos:0" href="https://login.yahoo.co.jp/config/login?.src=quote&amp;.intl=jp&amp;.done=https%3A%2F%2Fstocks.finance.yahoo.co.jp%3A443%2Fstocks%2Fdetail%2F%3Fcode%3Dusdjpy">ログインしてポートフォリオを表示</a></li></ul>
# </div>
# </div>
# <!---/PORTFOLIO-->
# <div id="cat-pass">
# <!--delimita-->
# </div><!--/#cat-pass end-->
# </hr></hr></div><!--/#contents-header end-->
# <div id="contents-body">
# <span class="yj-guid"><a id="contents-start" name="contents-start"></a><img alt="ここから本文です" height="1" src="https://s.yimg.jp/images/clear.gif" width="1"/></span>
# <!--main start-->
# <div id="main">
# <noscript>
# <div class="alertBg yjSt marB10">
# <strong class="darkRed">現在JavaScriptが無効になっています。</strong>
# <p>Yahoo!ファイナンスのすべての機能を利用するためには、JavaScriptの設定を有効にしてください。<br>
# JavaScriptの設定を変更する方法は<a href="http://help.yahoo.co.jp/help/jp/common/sys/sys-07.html">こちら</a>。</br></p>
# </div>
# </noscript>
# <!-- 新規YDN -->
# <div id="finYdnInstant">
# <style type="text/css">
# #finYdnInstant div {
#     border-bottom: none !important;
#     font-family: 'ヒラギノ角ゴ Pro W3', 'Hiragino Kaku Gothic Pro', 'メイリオ', Meiryo, Osaka, 'ＭＳ Ｐゴシック', 'MS PGothic', sans-serif !important;
# }
# #finYdnInstant div div {
#     margin: -5px 0 5px 0 !important;
# }
# </style>
# <script language="JavaScript" type="text/javascript">
# yads_ad_ds = '11279_33601';
# yads_type_tag ='financestock';
# </script>
# <script language="JavaScript" src="//yads.c.yimg.jp/js/yads.js" type="text/javascript"></script>
# </div>
# <!-- /新規YDN -->
# <!--empty-->
# <!--/empty-->
# <div class="clearFix">
# <div class="stocksSetting yjS">
# <span class="reload"><em>自動</em> | <a data-ylk="slk:manual;pos:0" href="http://rdsig.yahoo.co.jp/finance/stocks/142mnl/RV=1/RU=aHR0cHM6Ly9zdG9ja3MuZmluYW5jZS55YWhvby5jby5qcC9zdG9ja3MvcmVnaXN0ZXIvdXBzPy5kb25lPWh0dHBzJTNBJTJGJTJGc3RvY2tzLmZpbmFuY2UueWFob28uY28uanAlM0E0NDMlMkZzdG9ja3MlMkZkZXRhaWwlMkYlM0Zjb2RlJTNEdXNkanB5">手動</a></span> </div>
# <!-- socialPlugin -->
# <div class="socialPlugin">
# <a class="fbShare" href="http://www.facebook.com/sharer.php?u=https%3A%2F%2Fstocks.finance.yahoo.co.jp%3A443%2Fstocks%2Fdetail%2F%3Fcode%3Dusdjpy" target="new"><img alt="Facebookにシェア" height="18" src="https://s.yimg.jp/images/finance/common/image/fb_btn.png" width="59"/></a>
# <div class="twitter">
# <a class="twitter-share-button" data-count="none" href="https://twitter.com/share">ツイート</a>
# <script>!function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0],p=/^http:/.test(d.location)?'http':'https';if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src=p+'://platform.twitter.com/widgets.js';fjs.parentNode.insertBefore(js,fjs);}}(document, 'script', 'twitter-wjs');</script>
# </div>
# </div>
# <!-- socialPlugin -->
# </div>
# <!-- NEW STOCKS DETAIL -->
# <div class="stocksDtlWp">
# <div class="stocksDtl clearFix">
# <div class="add" id="divAddPortfolio"><a href="http://rdsig.yahoo.co.jp/finance/investment/exchange/detail/103addt/RV=1/RU=aHR0cHM6Ly9pbmZvLmZpbmFuY2UueWFob28uY28uanAvcG9ydGZvbGlvL2FkZC8_Y29kZT1VU0RKUFk9WCYuY2FuY2VsPWh0dHBzJTNBJTJGJTJGc3RvY2tzLmZpbmFuY2UueWFob28uY28uanAlM0E0NDMlMkZzdG9ja3MlMkZkZXRhaWwlMkYlM0Zjb2RlJTNEdXNkanB5"></a></div>
# <div class="forAddPortfolio">
# <dl class="stocksInfo clearFix">
# <dt>USDJPY=X</dt>
# <dd class="category yjSb">外国為替</dd>
# <dd class="yjSb real"><span>22:59</span></dd>
# </dl>
# <table class="stocksTable" summary="株価詳細">
# <tr>
# <th class="symbol"><h1>アメリカ　ドル / 日本　円</h1></th>
# <td class="stoksPrice">113.630000</td>
# </tr>
# </table>
# </div>
# </div>
# <!-- /NEW STOCKS DETAIL -->
# <ul class="subNavi yjSm">
# <li class="st01 crt">詳細情報</li>
# <li><a href="http://rdsig.yahoo.co.jp/finance/stocks/detail/104cht/RV=1/RU=aHR0cHM6Ly9zdG9ja3MuZmluYW5jZS55YWhvby5jby5qcC9zdG9ja3MvY2hhcnQvP2NvZGU9VVNESlBZPVg-">チャート</a></li>
# <li><a href="http://rdsig.yahoo.co.jp/finance/stocks/detail/104rcht/RV=1/RU=aHR0cHM6Ly9pbmZvLmZpbmFuY2UueWFob28uY28uanAvZngvZGV0YWlsLz9jb2RlPVVTREpQWT1GWA--">リアルタイムチャート</a></li>
# <li><a href="http://rdsig.yahoo.co.jp/finance/stocks/detail/105tbl/RV=1/RU=aHR0cHM6Ly9zdG9ja3MuZmluYW5jZS55YWhvby5jby5qcC9zdG9ja3MvaGlzdG9yeS8_Y29kZT1VU0RKUFk9WA--">時系列</a></li>
# <li><a href="http://rdsig.yahoo.co.jp/finance/stocks/detail/106nws/RV=1/RU=aHR0cHM6Ly9zdG9ja3MuZmluYW5jZS55YWhvby5jby5qcC9zdG9ja3MvbmV3cy8_Y29kZT1VU0RKUFk9WA--">ニュース</a></li>
# <li><a href="http://rdsig.yahoo.co.jp/finance/stocks/detail/109bbs/RV=1/RU=aHR0cDovL3RleHRyZWFtLnlhaG9vLmNvLmpwL3JkL2V4Y2hhbmdlL1VTREpQWQ--">掲示板</a></li>
# <li><a href="http://rdsig.yahoo.co.jp/finance/stocks/detail/131mgs/RV=1/RU=aHR0cHM6Ly9pbmZvLmZpbmFuY2UueWFob28uY28uanAvZngv">外国為替情報</a></li>
# </ul>
# </div>
# <!-- /NEW STOCKS DETAIL WAPPER -->
# <!--詳細情報-->
# <div class="marB6 chartFinance clearFix">
# <div class="ymuiEditLink yjSt styleChart padT12">
# <a href="/stocks/chart/?code=USDJPY=X&amp;ct=z&amp;t=1m"><img alt="チャート画像" src="https://chart.yahoo.co.jp/?code=USDJPY=X&amp;tm=1m&amp;size=e"/></a><br>期間：<strong>1か月</strong><span> | </span><a href="http://rdsig.yahoo.co.jp/finance/stocks/detail/151mth3/RV=1/RU=aHR0cHM6Ly9zdG9ja3MuZmluYW5jZS55YWhvby5jby5qcC9zdG9ja3MvZGV0YWlsLz9jb2RlPVVTREpQWT1YJmQ9M20-">3か月</a><span> | </span><a href="http://rdsig.yahoo.co.jp/finance/stocks/detail/113mth6/RV=1/RU=aHR0cHM6Ly9zdG9ja3MuZmluYW5jZS55YWhvby5jby5qcC9zdG9ja3MvZGV0YWlsLz9jb2RlPVVTREpQWT1YJmQ9Nm0-">6か月</a><span> | </span><a href="http://rdsig.yahoo.co.jp/finance/stocks/detail/114yer/RV=1/RU=aHR0cHM6Ly9zdG9ja3MuZmluYW5jZS55YWhvby5jby5qcC9zdG9ja3MvZGV0YWlsLz9jb2RlPVVTREpQWT1YJmQ9MXk-">1年</a><br><div class="popPosition" style="color:#000;"><a class="chartAncherBG" href="https://login.yahoo.co.jp/config/login?.src=quote&amp;.intl=jp&amp;.done=https%3A%2F%2Fstocks.finance.yahoo.co.jp%3A443%2Fstocks%2Fdetail%2F%3Fcode%3Dusdjpy">ログインするとチャートの期間を保存できます</a><div class="popUpFi" id="setModule" style="display:none;">
# <div class="yjSt marB4 popUpfiTitle">
# <a href="javascript:void(0);" onmousedown="set_close(); return false;"><span class="btnClose">閉じる</span></a>
# <strong>期間を保存する</strong>
# </div>
# <div class="yjSt popUpFiBd">この期間を保存しますか？</div>
# <div class="yjSt marB4 popUpFiBd centerFi">
# <form action="https://stocks.finance.yahoo.co.jp/stocks/register/top" method="get">
# <input name="code" type="hidden" value="USDJPY=X">
# <input name="d" type="hidden" value="1m">
# <input class="tourokuSubmit" type="submit" value="はい"> <input class="cancelReset" onmousedown="set_close(); return false;" type="reset" value="いいえ">
# </input></input></input></input></form>
# </div>
# </div>
# </div></br></br></div>
# <div class="innerDate">
# <div class="lineFi clearfix">
# <dl>
# <dd class="ymuiEditLink mar0"><strong>113.630000</strong><span class="date yjSt">（22:59）</span></dd>
# <dt class="title">買気配（ビッド）<a class="tips alignPos" href="https://info.finance.yahoo.co.jp/dictionary/" onmouseout="hideTips('kaikehai');" onmouseover="showTips('kaikehai');"><img onmouseout="this.src='https://s.yimg.jp/images/finance/common/image/btn_yougo.png'" onmouseover="this.src='https://s.yimg.jp/images/finance/common/image/btn_yougo_on.png'" src="https://s.yimg.jp/images/finance/common/image/btn_yougo.png"/></a>
# <span class="tips yjSt" id="kaikehai">買い手が提示するレート</span></dt>
# </dl>
# </div>
# <div class="lineFi clearfix">
# <dl>
# <dd class="ymuiEditLink mar0"><strong>113.640000</strong><span class="date yjSt">（22:59）</span></dd>
# <dt class="title">売気配（オファー）<a class="tips alignPos" href="https://info.finance.yahoo.co.jp/dictionary/" onmouseout="hideTips('urikehai');" onmouseover="showTips('urikehai');"><img onmouseout="this.src='https://s.yimg.jp/images/finance/common/image/btn_yougo.png'" onmouseover="this.src='https://s.yimg.jp/images/finance/common/image/btn_yougo_on.png'" src="https://s.yimg.jp/images/finance/common/image/btn_yougo.png"/></a>
# <span class="tips yjSt" id="urikehai">売り手が提示するレート</span></dt>
# </dl>
# </div>
# </div>
# </div>
# <!--/詳細情報-->
# <table class="kabuyosoInsite yjSt">
# <tr>
# <th class="wakuFiIn"><strong class="marR6">株価予想</strong></th>
# <td><p><a href="http://rdsig.yahoo.co.jp/finance/investment/exchange/detail/kabuyoso/RV=1/RU=aHR0cHM6Ly9pbmZvLmZpbmFuY2UueWFob28uY28uanAva2FidXlvc28vbWFya2V0L3VzZGpweS8-">どうなる？明日の米国ドル</a></p>
# </td>
# </tr>
# </table>
# <!--アフィニティ-->
# <div class="ymuiHeaderBGLight ymui3DHeader"><div>
# <h2 class="ymuiTitle yjS">この銘柄を見た人はこんな銘柄も見ています</h2></div></div>
# <div class="marB10 ymuiBodyBorder clearFix yjMS padL4" id="tprc">
# <ol class="affirank">
# <li><span class="affirank1">1<em class="yjS">位</em></span><a href="https://stocks.finance.yahoo.co.jp/stocks/detail/?code=AUDTHB=X&amp;serviceKanriId=AUDTHB=X&amp;pos=1&amp;ccode=ofv" onmousedown="this.href='https://stocks.finance.yahoo.co.jp/stocks/detail/?code=AUDTHB=X&amp;serviceKanriId=AUDTHB=X&amp;pos=1&amp;ccode=ofv'">豪州ドル</a></li><li><span class="affirank2">2<em class="yjS">位</em></span><a href="https://stocks.finance.yahoo.co.jp/stocks/detail/?code=USDUSD=X&amp;serviceKanriId=USDUSD=X&amp;pos=2&amp;ccode=ofv" onmousedown="this.href='https://stocks.finance.yahoo.co.jp/stocks/detail/?code=USDUSD=X&amp;serviceKanriId=USDUSD=X&amp;pos=2&amp;ccode=ofv'">米国ドル</a></li><li><span class="affirank3">3<em class="yjS">位</em></span><a href="https://stocks.finance.yahoo.co.jp/stocks/detail/?code=EURTWD=X&amp;serviceKanriId=EURTWD=X&amp;pos=3&amp;ccode=ofv" onmousedown="this.href='https://stocks.finance.yahoo.co.jp/stocks/detail/?code=EURTWD=X&amp;serviceKanriId=EURTWD=X&amp;pos=3&amp;ccode=ofv'">ユーロ</a></li><li><span class="affirank4">4<em class="yjS">位</em></span><a href="https://stocks.finance.yahoo.co.jp/stocks/detail/?code=CNYPHP=X&amp;serviceKanriId=CNYPHP=X&amp;pos=4&amp;ccode=ofv" onmousedown="this.href='https://stocks.finance.yahoo.co.jp/stocks/detail/?code=CNYPHP=X&amp;serviceKanriId=CNYPHP=X&amp;pos=4&amp;ccode=ofv'">中国元</a></li><li><span class="affirank4">5<em class="yjS">位</em></span><a href="https://stocks.finance.yahoo.co.jp/stocks/detail/?code=GBPUSD=X&amp;serviceKanriId=GBPUSD=X&amp;pos=5&amp;ccode=ofv" onmousedown="this.href='https://stocks.finance.yahoo.co.jp/stocks/detail/?code=GBPUSD=X&amp;serviceKanriId=GBPUSD=X&amp;pos=5&amp;ccode=ofv'">英国ポンド</a></li><li class="ymuiEditLink"><a class="icoMore marL10" data-ylk="slk:more;pos:0" href="#affinity">もっと見る</a></li></ol>
# </div>
# <!--/アフィニティ-->
# <!--empty-->
# <!--/empty-->
# <div class="achartArea" id="achart">
# <div class="achartBox clearFix">
# <div class="achartEntrance"><a href="https://info.finance.yahoo.co.jp/achart/stock/?Code=usdjpy=x" target="_blank">テクニカル分析用多機能チャート </a></div>
# <div class="achartPowerd">Powerd by Works Technology</div>
# </div></div>
# <a name="affinity"></a>
# <!--ADユニット1表示コード-->
# <div id="ydn-bot">
# <div id="yads_ds61769_14543_01"></div></div>
# <!--YJFX Banner-->
# <div class="marB10">
# <a href="http://r.ca-mpr.jp/s/104/?i4a=937670">
# <img alt="YJFX口座開設" height="80" src="https://s.yimg.jp/images/finance/reuterspage/yjfx/201612/634_80.png" title="YJFX口座開設" width="634">
# </img></a>
# </div>
# <!--アフィニティ-->
# <div id="ftrc">
# <div class="ymuiHeaderBGLight ymui3DHeader"><div>
# <h2 class="ymuiTitle yjS">この銘柄を見た人はこんな銘柄も見ています</h2></div></div>
# <div class="marB10 ymuiBodyBorder clearFix yjMS padL4">
# <ol class="affirank">
# <li><span class="affirank4">6<em class="yjS">位</em></span><a href="https://stocks.finance.yahoo.co.jp/stocks/detail/?code=USDHKD=X&amp;serviceKanriId=USDHKD=X&amp;pos=6&amp;ccode=ofv" onmousedown="this.href='https://stocks.finance.yahoo.co.jp/stocks/detail/?code=USDHKD=X&amp;serviceKanriId=USDHKD=X&amp;pos=6&amp;ccode=ofv'">米国ドル</a></li>
# <li><span class="affirank4">7<em class="yjS">位</em></span><a href="https://stocks.finance.yahoo.co.jp/stocks/detail/?code=AUDGBP=X&amp;serviceKanriId=AUDGBP=X&amp;pos=7&amp;ccode=ofv" onmousedown="this.href='https://stocks.finance.yahoo.co.jp/stocks/detail/?code=AUDGBP=X&amp;serviceKanriId=AUDGBP=X&amp;pos=7&amp;ccode=ofv'">豪州ドル</a></li>
# <li><span class="affirank4">8<em class="yjS">位</em></span><a href="https://stocks.finance.yahoo.co.jp/stocks/detail/?code=EURUSD=X&amp;serviceKanriId=EURUSD=X&amp;pos=8&amp;ccode=ofv" onmousedown="this.href='https://stocks.finance.yahoo.co.jp/stocks/detail/?code=EURUSD=X&amp;serviceKanriId=EURUSD=X&amp;pos=8&amp;ccode=ofv'">ユーロ</a></li>
# <li><span class="affirank4">9<em class="yjS">位</em></span><a href="https://stocks.finance.yahoo.co.jp/stocks/detail/?code=CADUSD=X&amp;serviceKanriId=CADUSD=X&amp;pos=9&amp;ccode=ofv" onmousedown="this.href='https://stocks.finance.yahoo.co.jp/stocks/detail/?code=CADUSD=X&amp;serviceKanriId=CADUSD=X&amp;pos=9&amp;ccode=ofv'">カナダドル</a></li>
# <li><span class="affirank4">10<em class="yjS">位</em></span><a href="https://stocks.finance.yahoo.co.jp/stocks/detail/?code=9R31110B&amp;serviceKanriId=9R31110B&amp;pos=10&amp;ccode=ofv" onmousedown="this.href='https://stocks.finance.yahoo.co.jp/stocks/detail/?code=9R31110B&amp;serviceKanriId=9R31110B&amp;pos=10&amp;ccode=ofv'">中国人民元マネジメント債券ファンド(毎月)</a></li>
# <li><span class="affirank4">11<em class="yjS">位</em></span><a href="https://stocks.finance.yahoo.co.jp/stocks/detail/?code=IDRPHP=X&amp;serviceKanriId=IDRPHP=X&amp;pos=11&amp;ccode=ofv" onmousedown="this.href='https://stocks.finance.yahoo.co.jp/stocks/detail/?code=IDRPHP=X&amp;serviceKanriId=IDRPHP=X&amp;pos=11&amp;ccode=ofv'">インドネシ</a></li>
# <li><span class="affirank4">12<em class="yjS">位</em></span><a href="https://stocks.finance.yahoo.co.jp/stocks/detail/?code=JPYUSD=X&amp;serviceKanriId=JPYUSD=X&amp;pos=12&amp;ccode=ofv" onmousedown="this.href='https://stocks.finance.yahoo.co.jp/stocks/detail/?code=JPYUSD=X&amp;serviceKanriId=JPYUSD=X&amp;pos=12&amp;ccode=ofv'">日本円</a></li>
# <li><span class="affirank4">13<em class="yjS">位</em></span><a href="https://stocks.finance.yahoo.co.jp/stocks/detail/?code=EURJPY=X&amp;serviceKanriId=EURJPY=X&amp;pos=13&amp;ccode=ofv" onmousedown="this.href='https://stocks.finance.yahoo.co.jp/stocks/detail/?code=EURJPY=X&amp;serviceKanriId=EURJPY=X&amp;pos=13&amp;ccode=ofv'">ユーロ</a></li>
# <li><span class="affirank4">14<em class="yjS">位</em></span><a href="https://stocks.finance.yahoo.co.jp/stocks/detail/?code=AUDJPY=X&amp;serviceKanriId=AUDJPY=X&amp;pos=14&amp;ccode=ofv" onmousedown="this.href='https://stocks.finance.yahoo.co.jp/stocks/detail/?code=AUDJPY=X&amp;serviceKanriId=AUDJPY=X&amp;pos=14&amp;ccode=ofv'">豪州ドル</a></li>
# <li><span class="affirank4">15<em class="yjS">位</em></span><a href="https://stocks.finance.yahoo.co.jp/stocks/detail/?code=02311166&amp;serviceKanriId=02311166&amp;pos=15&amp;ccode=ofv" onmousedown="this.href='https://stocks.finance.yahoo.co.jp/stocks/detail/?code=02311166&amp;serviceKanriId=02311166&amp;pos=15&amp;ccode=ofv'">グローバル･オイル株式ファンド</a></li>
# </ol>
# </div>
# </div>
# <!--/アフィニティ-->
# <!---AD SQB-->
# <!-- AD START Location SQB -->
# <div class="sqbFiAd">
# <!-- SpaceID=0 robot -->
# </div>
# <!-- AD END Location SQB -->
# <!---/AD SQB-->
# <!--ADユニット2表示コード-->
# <div id="yads_ds61769_14543_02"></div>
# </div><!--/#main end-->
# <!--/main end-->
# <!--sub start-->
# <div id="sub">
# <div id="pos-lrec">
# <dl><!-- SpaceID=0 robot -->
# </dl>
# </div><!--/#pos-lrec end--><div id="promo">
# <!-- settlement -->
# <div class="marB10">
# <a href="https://rdsig.yahoo.co.jp/finance/promotion/funds/yjamlight/pc/stock/right/RV=1/RU=aHR0cHM6Ly9maW5hbmNlLnlhaG9vLmNvLmpwL2ZlYXR1cmUvcHJvbW90aW9uL2Z1bmRzL3lqYW1saWdodC5odG1s">
# <img alt="Yjamシリーズ第2弾 運用開始" height="60" src="https://s.yimg.jp/images/finance/bnr/201703/yjamligjt_300_60.png" title="これだけで世界に投資！Yjamシリーズ第2弾 運用開始
# " width="300">
# </img></a>
# </div>
# <!-- /settlement --></div><!-- promotion random -->
# <div class="ymuiHeaderBGLight ymui3DHeader"><div><h2 class="ymuiTitle yjMS">Yahoo!ファイナンスからのお知らせ</h2></div></div>
# <div class="ymuiContainer ymuiBodyBorder yjSt clearFix" id="promordm">
# <a href="http://rdsig.yahoo.co.jp/finance/stocks/right/prom/link2/RV=1/RU=aHR0cDovL3Jkc2lnLnlhaG9vLmNvLmpwL2ZpbmFuY2UvdG9wL3Byb21vL3N0b2Nrcy9zaWRlMS9SVj0xL1JVPWFIUjBjRG92TDJsdVptOHVabWx1WVc1alpTNTVZV2h2Ynk1amJ5NXFjQzkyYVhBdmNISXY-"><img alt="VIP倶楽部 有料ニュース800本も初月無料！ " height="" src="https://s.yimg.jp/images/finance/common/image/bn_vipclub.png" width="289"/></a>
# </div>
# <!-- /promotion random -->
# <!--RANKING-->
# <div class="ymuiHeaderBGLight ymui3DHeader"><div><h2 class="ymuiTitle yjMS">株式ランキング</h2></div></div>
# <div class="ymuiContainerNopad ymuiBodyBorder" id="stockrnk">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td class="tableColLine" valign="top" width="50%">
# <dl class="yjSt">
# <dt class="DataTitle clearfix"><span class="floatL">値上がり率</span><span class="floatR"><strong class="greenFin">1629</strong><span class="textNormal">社</span></span></dt>
# <dd class="DataText greyBG clearfix"><span class="floatL">1. <a data-ylk="slk:up;pos:1" href="http://rdsig.yahoo.co.jp/finance/stocks/ranking/up/20d/RV=1/RU=aHR0cDovL3N0b2Nrcy5maW5hbmNlLnlhaG9vLmNvLmpwL3N0b2Nrcy9kZXRhaWwvP2NvZGU9MjE1MC5U">ケアネット</a></span><span class="floatR"><strong class="greenFin">+28.52</strong>％</span></dd>
# <dd class="DataText clearfix"><span class="floatL">2. <a data-ylk="slk:up;pos:2" href="http://rdsig.yahoo.co.jp/finance/stocks/ranking/up/20d/RV=1/RU=aHR0cDovL3N0b2Nrcy5maW5hbmNlLnlhaG9vLmNvLmpwL3N0b2Nrcy9kZXRhaWwvP2NvZGU9MzIzMS5U">野村不ＨＤ</a></span><span class="floatR"><strong class="greenFin">+24.65</strong>％</span></dd>
# <dd class="DataText greyBG clearfix"><span class="floatL">3. <a data-ylk="slk:up;pos:3" href="http://rdsig.yahoo.co.jp/finance/stocks/ranking/up/20d/RV=1/RU=aHR0cDovL3N0b2Nrcy5maW5hbmNlLnlhaG9vLmNvLmpwL3N0b2Nrcy9kZXRhaWwvP2NvZGU9MjQ3NS5U">ＷＤＢＨＤ</a></span><span class="floatR"><strong class="greenFin">+24.38</strong>％</span></dd>
# <dd class="pad4 clearfix"><strong class="floatR"><a class="seeMore icoMore" data-ylk="slk:more;pos:1" href="http://rdsig.yahoo.co.jp/finance/stocks/ranking/up_more/20d/RV=1/RU=aHR0cDovL2luZm8uZmluYW5jZS55YWhvby5jby5qcC9yYW5raW5nLz9rZD0xJnRtPWQmbWs9MQ--">もっと見る</a></strong></dd>
# </dl>
# </td><td valign="top" width="50%">
# <dl class="yjSt">
# <dt class="DataTitle clearfix"><span class="floatL">値下がり率</span><span class="floatR"><strong class="redFin">1953</strong><span class="textNormal">社</span></span></dt>
# <dd class="DataText greyBG clearfix"><span class="floatL">1. <a data-ylk="slk:down;pos:1" href="http://rdsig.yahoo.co.jp/finance/stocks/ranking/down/20d/RV=1/RU=aHR0cDovL3N0b2Nrcy5maW5hbmNlLnlhaG9vLmNvLmpwL3N0b2Nrcy9kZXRhaWwvP2NvZGU9NzE5Mi5U">日本モゲジ</a></span><span class="floatR"><strong class="redFin">-17.90</strong>％</span></dd>
# <dd class="DataText clearfix"><span class="floatL">2. <a data-ylk="slk:down;pos:2" href="http://rdsig.yahoo.co.jp/finance/stocks/ranking/down/20d/RV=1/RU=aHR0cDovL3N0b2Nrcy5maW5hbmNlLnlhaG9vLmNvLmpwL3N0b2Nrcy9kZXRhaWwvP2NvZGU9NTk1My5G">昭和鉄</a></span><span class="floatR"><strong class="redFin">-17.23</strong>％</span></dd>
# <dd class="DataText greyBG clearfix"><span class="floatL">3. <a data-ylk="slk:down;pos:3" href="http://rdsig.yahoo.co.jp/finance/stocks/ranking/down/20d/RV=1/RU=aHR0cDovL3N0b2Nrcy5maW5hbmNlLnlhaG9vLmNvLmpwL3N0b2Nrcy9kZXRhaWwvP2NvZGU9Njg5NS5U">ダイヤ電</a></span><span class="floatR"><strong class="redFin">-17.15</strong>％</span></dd>
# <dd class="pad4 clearfix"><strong class="floatR"><a class="seeMore icoMore" data-ylk="slk:more;pos:2" href="http://rdsig.yahoo.co.jp/finance/stocks/ranking/down_more/20d/RV=1/RU=aHR0cDovL2luZm8uZmluYW5jZS55YWhvby5jby5qcC9yYW5raW5nLz9rZD0yJnRtPWQmbWs9MQ--">もっと見る</a></strong></dd>
# </dl>
# </td>
# </tr>
# </table>
# </div>
# <!--/RANKING--><div class="ymuiHeaderBGLight ymui3DHeader"><div><h2 class="ymuiTitle yjMS">プロが選ぶチャンス銘柄 予想中一覧</h2></div></div>
# <div class="ymuiContainer ymuiBodyBorder yjSt clearFix" id="kabuyoso">
# <ul class="kabuyosoRight winSpecialist2 noimg">
# <li class="sp">
# <dl>
# <dt class="yjS ymuiArrow1"><a data-ylk="slk:rcstock;pos:1" href="http://rdsig.yahoo.co.jp/finance/investment/stock/common/now/title/RV=1/RU=aHR0cHM6Ly9pbmZvLmZpbmFuY2UueWFob28uY28uanAva2FidXlvc28vYXJ0aWNsZS9kZXRhaWwvMjAxNzA1MTUtMDAwMDEyMTgtenV1b25saW5leS1zdG9ja3MtNjAxMg--">[買い] フィット</a>  <span class="iconConfidence" title="自信あり">自信あり</span> <span class="consecutive yjS" title="連勝中">4</span>
# </dt>
# <dd class="yjS floatR"><a data-ylk="slk:name;pos:1" href="http://rdsig.yahoo.co.jp/finance/investment/stock/common/now/name/RV=1/RU=aHR0cHM6Ly9pbmZvLmZpbmFuY2UueWFob28uY28uanAva2FidXlvc28vc3BlY2lhbGlzdC95b3NvLzYwMTI-">藤崎慎也</a></dd>
# </dl>
# </li>
# <li class="sp">
# <dl>
# <dt class="yjS ymuiArrow1"><a data-ylk="slk:rcstock;pos:2" href="http://rdsig.yahoo.co.jp/finance/investment/stock/common/now/title/RV=1/RU=aHR0cHM6Ly9pbmZvLmZpbmFuY2UueWFob28uY28uanAva2FidXlvc28vYXJ0aWNsZS9kZXRhaWwvMjAxNzA0MjYtMDAwNDE0NTktbWlua2FidXktc3RvY2tzLTUxMTQ-">[買い] タカギセイ</a>
# </dt>
# <dd class="yjS floatR"><a data-ylk="slk:name;pos:2" href="http://rdsig.yahoo.co.jp/finance/investment/stock/common/now/name/RV=1/RU=aHR0cHM6Ly9pbmZvLmZpbmFuY2UueWFob28uY28uanAva2FidXlvc28vc3BlY2lhbGlzdC95b3NvLzUxMTQ-">本田隆一郎</a></dd>
# </dl>
# </li>
# <li class="sp">
# <dl>
# <dt class="yjS ymuiArrow1"><a data-ylk="slk:rcstock;pos:3" href="http://rdsig.yahoo.co.jp/finance/investment/stock/common/now/title/RV=1/RU=aHR0cHM6Ly9pbmZvLmZpbmFuY2UueWFob28uY28uanAva2FidXlvc28vYXJ0aWNsZS9kZXRhaWwvMjAxNzA0MjQtMDAwNDEzNzUtbWlua2FidXktc3RvY2tzLTUwMjA-">[売り] 大塚ＨＬＤ</a>
# </dt>
# <dd class="yjS floatR"><a data-ylk="slk:name;pos:3" href="http://rdsig.yahoo.co.jp/finance/investment/stock/common/now/name/RV=1/RU=aHR0cHM6Ly9pbmZvLmZpbmFuY2UueWFob28uY28uanAva2FidXlvc28vc3BlY2lhbGlzdC95b3NvLzUwMjA-">西村剛</a></dd>
# </dl>
# </li>
# </ul>
# <div class="ymuiDotHr"></div>
# <ul class="ymuiSeeMore yjSt">
# <li><a class="icoMore marL10" data-ylk="slk:more;pos:0" href="http://rdsig.yahoo.co.jp/finance/investment/stock/common/now/more/RV=1/RU=aHR0cHM6Ly9pbmZvLmZpbmFuY2UueWFob28uY28uanAva2FidXlvc28vYXJ0aWNsZS9zdG9ja3Mvbm93Lw--">日本株の予想をもっと見る（予想中：81件）</a></li>
# </ul>
# </div>
# <div class="ymuiHeaderBGLight ymui3DHeader"><div><h2 class="ymuiTitle yjMS">ヘッドライン</h2></div></div>
# <div class="ymuiContainer ymuiBodyBorder" id="headline">
# <ul class="ymuiList yjSt">
# <li class="ymuiArrow2 s130 headlineBlock clearFix">
# <a href="http://rdsig.yahoo.co.jp/finance/sapu/ilu1/RV=1/RU=aHR0cHM6Ly9uZXdzLmZpbmFuY2UueWFob28uY28uanAvZGV0YWlsLzIwMTcwNTE1LTAwMDAwNjQ2LWppamYtbWFya2V0"><span class="headlineBlockLine">〔米株式〕NYダウ、反発＝ナスダックは続伸（15日朝）</span> <span class="ymuiDate yjSt">（時事通信）</span></a>
# </li>
# </ul>
# <ul class="ymuiList yjSt">
# <li class="ymuiArrow2 s130 headlineBlock clearFix">
# <a href="http://rdsig.yahoo.co.jp/finance/sapu/ilu2/RV=1/RU=aHR0cHM6Ly9uZXdzLmZpbmFuY2UueWFob28uY28uanAvZGV0YWlsLzIwMTcwNTE1LTAwMDAwNjQ0LWppamYtbWFya2V0"><span class="headlineBlockLine">〔NY外為〕円、113円台前半（15日朝）</span><span class="headlineBlockpointer" title="NEW"> </span> <span class="ymuiDate yjSt">（時事通信）</span></a>
# </li>
# </ul>
# <ul class="ymuiList yjSt">
# <li class="ymuiArrow2 s130 headlineBlock clearFix">
# <a href="http://rdsig.yahoo.co.jp/finance/sapu/ilu3/RV=1/RU=aHR0cHM6Ly9uZXdzLmZpbmFuY2UueWFob28uY28uanAvZGV0YWlsLzIwMTcwNTE1LTAwMDAwMDU2LWR6aC1meA--"><span class="headlineBlockLine">NY株見通し-政権運営と利上げ見通しに不透感が強まる</span> <span class="ymuiDate yjSt">（トレーダーズ・ウェブ）</span></a>
# </li>
# </ul>
# <ul class="ymuiList yjSt">
# <li class="ymuiArrow2 s130 headlineBlock clearFix">
# <a href="http://rdsig.yahoo.co.jp/finance/sapu/ilu4/RV=1/RU=aHR0cHM6Ly9uZXdzLmZpbmFuY2UueWFob28uY28uanAvZGV0YWlsLzIwMTcwNTE1LTAwMDAwNjE1LXN0a21zLXN0b2Nrcw--"><span class="headlineBlockLine">【明日の好悪材料】を開示情報でチェック！ (5月15日発表分)</span> <span class="ymuiDate yjSt">（株探ニュース）</span></a>
# </li>
# </ul>
# <ul class="ymuiList yjSt">
# <li class="ymuiArrow2 s130 headlineBlock clearFix">
# <a href="http://rdsig.yahoo.co.jp/finance/sapu/ilu5/RV=1/RU=aHR0cHM6Ly9uZXdzLmZpbmFuY2UueWFob28uY28uanAvZGV0YWlsLzIwMTcwNTE1LTAwMDAwMDYyLWR6aC1meA--"><span class="headlineBlockLine">ユーロ円、16年4月以来の125円台が視野に</span> <span class="ymuiDate yjSt">（トレーダーズ・ウェブ）</span></a>
# </li>
# </ul>
# <ul class="ymuiList yjSt">
# <li class="ymuiArrow2 s130 headlineBlock clearFix">
# <a href="http://rdsig.yahoo.co.jp/finance/sapu/ilu6/RV=1/RU=aHR0cHM6Ly9uZXdzLmZpbmFuY2UueWFob28uY28uanAvZGV0YWlsLzIwMTcwNTE1LTAwMTcxODA2LXNoaWtpaG8tY29sdW1u"><span class="headlineBlockLine">急落懸念もある5月、「日経平均2万円超え」の条件とは</span> <span class="ymuiDate yjSt">（会社四季報オンライン）</span></a>
# </li>
# </ul>
# <ul class="ymuiList yjSt">
# <li class="ymuiArrow2 s130 headlineBlock clearFix">
# <a href="http://rdsig.yahoo.co.jp/finance/sapu/ilu7/RV=1/RU=aHR0cHM6Ly9uZXdzLmZpbmFuY2UueWFob28uY28uanAvZGV0YWlsLzIwMTcwNTE1LTAwMDA0MTIzLWFyZ2VudC1jb2x1bW4-"><span class="headlineBlockLine">2017年夏 公務員のボーナス平均支給額</span> <span class="ymuiDate yjSt">（あるじゃん（All About マネー））</span></a>
# </li>
# </ul>
# <script language="JavaScript" type="text/javascript">yads_ad_ds = "91180_172622";</script>
# <script language="JavaScript" src="//yads.c.yimg.jp/js/yads.js" type="text/javascript"></script>
# <div class="ymuiDotHr"></div><!--点線-->
# <ul class="ymuiSeeMore yjSt">
# <li><a class="icoMore marL10" data-ylk="slk:more;pos:0" href="http://rdsig.yahoo.co.jp/finance/sapu/mlt/RV=1/RU=aHR0cDovL3Jkc2lnLnlhaG9vLmNvLmpwL2ZpbmFuY2UvdG9wL2FwdS9zbHUzL1JWPTEvUlU9YUhSMGNEb3ZMMjVsZDNNdVptbHVZVzVqWlM1NVlXaHZieTVqYnk1cWNDOW9aV0ZrYkdsdVpTOC0-">ヘッドラインをもっと見る</a></li>
# </ul>
# </div>
# <!-- SpaceID=0 robot -->
# <!-- SpaceID=0 robot -->
# <div class="marB10" id="rydn-mr">
# <script language="JavaScript" type="text/javascript">
# <!--
# yads_ad_ds = '33336_13701';
# //-->
# </script>
# <script language="JavaScript" src="//yads.c.yimg.jp/js/yads.js" type="text/javascript"></script>
# </div>
# <!-- SpaceID=0 robot -->
# <div id="yads_ds61769_14543_03"></div></div>
# <!--/sub end-->
# </div><!--/#contents-body end-->
# <div id="contents-footer">
# <span class="yj-guid"><img alt="本文はここまでです" height="1" src="https://s.yimg.jp/images/clear.gif" width="1"/></span>
# <span class="yj-skip">
# <a href="#pagetop"><img alt="このページの先頭へ" height="1" src="https://s.yimg.jp/images/clear.gif" width="1"/></a></span>
# </div><!--/#contents-footer end-->
# </div><!--/#contents end-->
# <!--/contents end-->
# <div class="ymuiContainer ymuiBodyBG yjSt" id="notice">
# <p class="darkRed"><strong>【ご注意】</strong></p>
# <ul class="ymuiList yjSt marB10">
# <li class="ymuiArrow1">市場を特定したい場合は、銘柄コードに続けて拡張子（例：4689.t）をつけてください。各市場の拡張子、詳細については<a href="http://help.yahoo.co.jp/help/jp/finance/quote/quote-02.html">こちら</a>をご覧ください。</li>
# <li class="ymuiArrow1">チャートについては、株式分割などがあった場合は分割日以前の取引値についてもさかのぼって修正を行っております。</li>
# <li class="ymuiArrow1">前日比については、権利落ちなどの修正を行っておりません。</li>
# <li class="ymuiArrow1">取引値は、東証、福証、札証はリアルタイムで、他市場は最低20分遅れで更新しています。</li>
# <li class="ymuiArrow1">全市場（東証、福証、札証も含む）の出来高・売買代金に関しては、最低20分遅れで表示しています。</li>
# <li class="ymuiArrow1">各項目の意味と更新頻度については「<a href="http://help.yahoo.co.jp/help/jp/finance/quote/quote-01.html">用語の説明</a>」をご覧ください。</li>
# </ul>
# Yahoo!ファイナンスは<a href="http://www.jpx.co.jp/corporate/jpx-profile/tse/index.html">東京証券取引所</a>、<a href="http://www.jpx.co.jp/corporate/jpx-profile/ose/index.html">大阪取引所</a>、<a href="http://www.nse.or.jp/">名古屋証券取引所</a>、<a href="http://www.nri.co.jp/">野村総合研究所</a>、<a href="http://www.toyokeizai.net/">東洋経済新報社</a>、<a href="http://jp.chi-x.com/index.html">チャイエックス・ジャパン</a>、<a href="http://www.morningstar.co.jp/">モーニングスター</a>、<a href="http://jp.reuters.com/">ロイター・ジャパン</a>、<a href="http://www.yjfx.jp/">YJFX!</a>、<a href="http://finance.yahoo.com/exchanges">米国Yahoo! Financeのパートナー</a>からの情報提供を受けています。<br>
# 日経平均株価の著作権は日本経済新聞社に帰属します。
# <p class="darkRed"><strong>当社は、この情報を用いて行う判断の一切について責任を負うものではありません。</strong></p>
# </br></div>
# <hr class="separation">
# <!--footer start-->
# <div id="footer">
# <!-- SpaceID=0 robot -->
# <address><a href="http://docs.yahoo.co.jp/docs/info/terms/chapter1.html#cf2nd">プライバシーポリシー</a> - <a href="http://docs.yahoo.co.jp/docs/info/terms/">利用規約</a> - <a href="http://docs.yahoo.co.jp/info/mediastatement/">メディアステートメント</a> - <a href="http://help.yahoo.co.jp/help/jp/finance/finance-27.html">免責事項（必ずお読みください）</a> - <a href="https://info.finance.yahoo.co.jp/vip/purchase/">特定商取引法の表示</a> - <a href="http://help.yahoo.co.jp/help/jp/finance/">ヘルプ・お問い合わせ</a> - <a href="http://rdsig.yahoo.co.jp/media/finance/footer/feedback/RV=1/RU=aHR0cHM6Ly9mZWVkYmFjay5tcy55YWhvby5jby5qcC92b2MvZmluYW5jZS12b2MvaW5wdXQ-">ご意見 ・ご要望</a><br>
#
# Copyright (C) 2017 Yahoo Japan Corporation. All Rights Reserved.</br></address>
# </div><!--/#footer end-->
# <!--/footer end-->
# </hr></hr></div><!--/#wrapper end-->
# <!--/wrapper end-->
# </body>
# <script type="text/javascript">
#     var alert_code = "USDJPY%3DX";
#     var fin_enc_recent_quote = "VfK3wT7wZE6IyHFM8MxAIJYKSzRGH9qkc0gEJ5fSeHPeGDrxs827TSmxCstsoLdV2XxtMeZ1HJ3hqZ6797T1EFInZQgnZs1nEYIx1Adkkb73.Me1FgvwUwjr1M23FKjJ";
# </script>
# <script language="JavaScript">
# <!--Tips-->
# var tipsTimerID;function showTips(nm){tipsTimerID = setTimeout(function(){var style=document.getElementById?document.getElementById(nm).style:(document.all?document.all(nm).style:(document.layers?document.layers[nm]:null));if(style) style.visibility='inherit';},500);}function hideTips(nm){clearTimeout(tipsTimerID);var style=document.getElementById?document.getElementById(nm).style:(document.all?document.all(nm).style:(document.layers?document.layers[nm]:null));if(style) style.visibility='hidden';}
# <!--OpenClosePort-->
# function port_open(){if(document.getElementById('portVisible').style.display == 'none'){document.getElementById('portVisible').style.display = 'block';document.getElementById('btnValueOpen').style.display = 'none';document.getElementById('btnValueClose').style.display = 'block';return false;}}function port_close(){if(document.getElementById('portVisible').style.display == 'block'){document.getElementById('portVisible').style.display = 'none';document.getElementById('btnValueOpen').style.display = 'block';document.getElementById('btnValueClose').style.display = 'none';return false;}}
# <!--OpenCloseSet-->
# function set_open(){if(document.getElementById('setModule').style.display == 'none'){document.getElementById('setModule').style.display = 'block';return false;}}function set_close(){if(document.getElementById('setModule').style.display == 'block'){document.getElementById('setModule').style.display = 'none';return false;}}
# function jump(s){location.href = "/stocks/detail/?code="+s;}
# function showOtherMarket(){
#     var otherMarket = document.getElementById('ulOtherMarket');
#     if (otherMarket) {
#         if (otherMarket.style.display == 'none') {
#             otherMarket.style.display = 'block';
#         } else {
#             otherMarket.style.display = 'none';
#         }
#     }
# }
# function overAddPortfolioButton() {
#     var addPortfolio = document.getElementById('divAddPortfolio');
#     if (addPortfolio) {
#         addPortfolio.className = "add hover";
#     }
# }
# function outAddPortfolioButton() {
#     var addPortfolio = document.getElementById('divAddPortfolio');
#     if (addPortfolio) {
#         addPortfolio.className = "add";
#     }
# }
# function downAddPortfolioButton() {
#     var addPortfolio = document.getElementById('divAddPortfolio');
#     if (addPortfolio) {
#         addPortfolio.className = "add down";
#     }
# }
# function upAddPortfolioButton() {
#     var addPortfolio = document.getElementById('divAddPortfolio');
#     if (addPortfolio) {
#         addPortfolio.className = "add";
#     }
# }
# (function(){
#     var marketSelect = document.getElementById('ddMarketSelect');
#     var addPortfolio = document.getElementById('divAddPortfolio');
#     if (marketSelect) {
#         try {
#             marketSelect.addEventListener('click', showOtherMarket, false);
#         } catch (e) {
#             marketSelect.attachEvent('onclick', showOtherMarket);
#         }
#     }
#     if (addPortfolio) {
#         try {
#             addPortfolio.addEventListener('mouseover', overAddPortfolioButton, false);
#         } catch (e) {
#             addPortfolio.attachEvent('onmouseover', overAddPortfolioButton);
#         }
#         try {
#             addPortfolio.addEventListener('mouseout', outAddPortfolioButton, false);
#         } catch (e) {
#             addPortfolio.attachEvent('onmouseout', outAddPortfolioButton);
#         }
#         try {
#             addPortfolio.addEventListener('mousedown', downAddPortfolioButton, false);
#         } catch (e) {
#             addPortfolio.attachEvent('onclick', downAddPortfolioButton);
#         }
#         try {
#             addPortfolio.addEventListener('mouseup', upAddPortfolioButton, false);
#         } catch (e) {
#             addPortfolio.attachEvent('onclick', upAddPortfolioButton);
#         }
#     }
# })();
# </script>
# <script type="text/javascript">
# function wo(url) {
#     url = url + '&cf=1';
#     window.open(url,'view','toolbar=no,location=no,directories=no,status=no,menubar=no,scrollbars=no,resizable=no,width=960,height=730');
# }
# </script>
# <script type="text/javascript">
# (function(){YjdCookie={set:function(a,b){var x=new XMLHttpRequest();x.open("GET",a,0);x.send();document.location.href=b;}}})();
# </script>
# <script src="/js/alert.js" type="text/javascript"></script>
# <script src="/js/flash_scroll.js" type="text/javascript"></script>
# <script src="/js/recent.js" type="text/javascript"></script>
# <script language="JavaScript" type="text/javascript">
# <!--
# yads_ad_ds = '61769_14543';
# //-->
# </script>
# <script language="JavaScript" src="//yads.c.yimg.jp/js/yads.js" type="text/javascript"></script>
# <script src="https://s.yimg.jp/images/ds/ult/finance/rapidjp-1.0.0.js"></script>
# <script src="https://s.yimg.jp/images/finance/smp/common/js/common-min.js"></script><script>(function() {
# var conf = {
# pagetype:'detail',
# conttype:'reutdtl',
# opttype:'pc',
# ctsid:'USDJPY=X',
# cat_path:'CURRENCY',
# status:'logout'
# };
# if (document.getElementById("msthd") !== null || document.getElementById("yjsmhHeader") !== null || document.getElementById("yjsmhMenu") !== null) {
# var sec_lists = ['msthd','headline','fin_rec','financeSearch'];
# } else {
# var sec_lists = ['headline','fin_rec','financeSearch'];
# }
# YAHOO.JP.fin.common.initSimpleRapid(conf, sec_lists, '2080289616');
# })();
# </script>
# </html>
#
# ----------------------------------
# usd/jpy= 113.630000

# %% [markdown]
# # 1-3 CSSセレクタ

# %%
from bs4 import BeautifulSoup
import urllib.request as req

# 為替情報XML取得
url = "http://www.aozora.gr.jp/index_pages/person148.html#sakuhin_list_1"
res = req.urlopen(url)
print(url)
print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")

# HTML解析
soup = BeautifulSoup(res, "html.parser")
print(soup)
print("----------------------------------")

li_list = soup.select("ol > li")
for li in li_list:
    a = li.a
    if a != None:
        name = a.string
        href = a.attrs["href"]
        print(name)
# Out:
# http://www.aozora.gr.jp/index_pages/person148.html#sakuhin_list_1
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# <html lang="ja">
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type">
# <meta content="text/css" http-equiv="Content-Style-Type">
# <title>作家別作品リスト：夏目 漱石</title>
# <style type="text/css">
# <!--
# body{
#     margin-left: 10%;
#     margin-right: 10%;
#     margin-bottom: 5%;
#     line-height: 150%;
# }
# a:hover{
#     color: white;
#     background-color: #0000ff;
# }
# h1{
#     color: black;
#     background-color: #ffffcc;
#     padding: 10pt;
#     border-color: black;
#     border-width: 1pt 0 1pt 0;
#     border-style: solid none solid none;
#     font-size: 150%;
# }
# h2{
#     color: black;
#     background-color: #d3d3d3;
#     padding: 5pt;
#     border-color: black;
#     border-width: 1pt 0 1pt 0;
#     border-style: solid none solid none;
#     text-indent: 1em;
# }
# table{
#     margin-left: 1em;
#     padding: 0.5em 0em 0.5em 1em;
# }
# table.download{
#     color: black;
#     margin-left: 0;
#     padding: 0;
# }
# th.download{
#     font-weight: bold;
#     background-color: black;
#     color: white;
# }
# td{
#     line-height:150%;
# }
# td.header{
#     vertical-align: top;
#     font-weight: bold;
#     width: 8em;
#     color: #a52a2a;
# }
# ol{
# <a href="person_all_ta.html">[た]</a>
# <a href="person_all_na.html">[な]</a>
# <a href="person_all_ha.html">[は]</a>
# <a href="person_all_ma.html">[ま]</a>
# <a href="person_all_ya.html">[や]</a>
# <a href="person_all_ra.html">[ら]</a>
# <a href="person_all_wa.html">[わ]</a>
# <a href="person_all_zz.html">[他]</a><br>
# ●<a href="../index.html">トップ</a>　●<a href="index_top.html">インデックス</a>／<a href="index_all.html">全</a></br></br></br></div>
# </hr></hr></body>
# </html>
# ----------------------------------
# イズムの功過
# 一夜
# 永日小品
# 岡本一平著並画『探訪画趣』序
# 思い出す事など
# カーライル博物館
# 薤露行
# 学者と名誉
# 硝子戸の中
# 元日
# 木下杢太郎『唐草表紙』序
# 教育と文芸
# 京に着ける夕
# 虚子君へ
# 草枕
# 虞美人草
# ケーベル先生
# ケーベル先生の告別
# 現代日本の開化
# 行人
# 坑夫
# こころ
# 『心』広告文
# 『心』自序
# 『心』予告
# 琴のそら音
# コンラッドの描きたる自然について
# 作物の批評
# 三山居士
# 三四郎
# 『三四郎』予告
# 子規の画
# 子規の画
# 「自然を写す文章」
# 自転車日記
# 写生文
# 趣味の遺伝
# 初秋の一日
# 処女作追懐談
# 人生
# 鈴木三重吉宛書簡―明治三十九年
# 西洋にはない
# 戦争からきた行き違い
# 創作家の態度
# それから
# それから
# 『それから』予告
# 高浜虚子著『鶏頭』序
# 田山花袋君に答う
# 「土」に就て
# 『土』に就て
# 艇長の遺書と中佐の詩
# 手紙
# 『伝説の時代』序
# 点頭録
# 『東洋美術図譜』
# 道楽と職業
# 長塚節氏の小説「土」
# 中味と形式
# 二百十日
# 入社の辞
# 猫の広告文
# 野分
# 『煤煙』の序
# 博士問題とマードック先生と余
# 博士問題の成行
# 長谷川君と余
# 彼岸過迄
# 「額の男」を読む
# 文芸委員は何をするか
# 文芸と道徳
# 文芸とヒロイツク
# 文芸の哲学的基礎
# 文芸は男子一生の事業とするに足らざる乎
# 文士の生活
# 文壇の趨勢
# 文鳥
# 変な音
# 変な音
# 僕の昔
# 坊っちゃん
# マードック先生の『日本歴史』
# 正岡子規
# 幻影の盾
# 満韓ところどころ
# 道草
# 無題
# 明暗
# 明治座の所感を虚子君に問れて
# 模倣と独立
# 門
# 夢十夜
# 余と万年筆
# 予の描かんと欲する作品
# 落第
# 倫敦消息
# 倫敦塔
# 吾輩は猫である
# 吾輩ハ猫デアル
# 『吾輩は猫である』下篇自序
# 『吾輩は猫である』上篇自序
# 『吾輩は猫である』中篇自序
# 私の経過した学生時代
# 私の個人主義

# %% [markdown]
# # 1-4 リンク先を丸ごとダウンロード

# %%
from urllib.parse import urljoin

base = "http://example.com/html/a.html"

print(urljoin(base, "b.html"))
print(urljoin(base, "sub/b.html"))
print(urljoin(base, "../b.html"))
print(urljoin(base, "../img/b.png"))
print(urljoin(base, "../css/hoge.css"))
# Out:
# http://example.com/html/b.html
# http://example.com/html/sub/b.html
# http://example.com/b.html
# http://example.com/img/b.png
# http://example.com/css/hoge.css
